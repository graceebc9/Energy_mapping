# %%
import os
import sys
import time
import geopandas as gpd 
import pandas as pd 
import glob 
import re
import matplotlib.pyplot as plt 
from shapely.geometry import Point, Polygon
from shapely.geometry import box

sys.path.append('/Users/gracecolverd/New_dataset')

from src.postcode_utils import find_postcode_for_ONSUD_file, find_data_pc 


# from src.postcode_utils  import find_postcode_for_ONSUD_file, find_data_pc

INPUT_GPK = '/Volumes/T9/Data_downloads/Versik_building_data/2024_03_22_updated_data/UKBuildings_Edition_15_new_format_upn.gpkg'

# %%
# p='/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291'
# pc_df , data = find_postcode_for_ONSUD_file('/Volumes/T9/Data_downloads/ONS_UPRN_database/ONSUD_DEC_2022/Data/ONSUD_DEC_2022_EM.csv' , p)

# %%
from src.postcode_utils import find_batch_from_pc , load_onsud_from_batch, get_postcode_shapefile,find_data_pc_joint

# %%
pc_shp = '/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291'


pc = 'B7 4QA'

bb = find_batch_from_pc(pc)
ons = load_onsud_from_batch(bb)
pcshp, d = find_postcode_for_ONSUD_file(ons, path_to_pc_shp_folder=pc_shp)
# Out:
# 103257
# Len of missing rows  0

# %%
pc_shp = '/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291'


pc = 'N1 2XD'

bb = find_batch_from_pc(pc)
ons = load_onsud_from_batch(bb)
pcshp, d = find_postcode_for_ONSUD_file(ons, path_to_pc_shp_folder=pc_shp)
uprn_match = find_data_pc_joint(pc, (d, pcshp), input_gpk=INPUT_GPK)
# Out:
# 324023
# Len of missing rows  0

# %%
pc_shp = '/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291'


pc = 'EC1Y 8NE'
# pc="EC2Y 8DJ"
# pc="EC1A 4LX"
bb = find_batch_from_pc(pc)
print(bb)
ons = load_onsud_from_batch(bb)
pcshp, d = find_postcode_for_ONSUD_file(ons, path_to_pc_shp_folder=pc_shp)
uprn_match = find_data_pc_joint(pc, (d, pcshp), input_gpk=INPUT_GPK)
# Out:
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 9
#       7 bb = find_batch_from_pc(pc)
#       8 print(bb)
# ----> 9 ons = load_onsud_from_batch(bb)
#      10 pcshp, d = find_postcode_for_ONSUD_file(ons, path_to_pc_shp_folder=pc_shp)
#      11 uprn_match = find_data_pc_joint(pc, (d, pcshp), input_gpk=INPUT_GPK)
#
# File ~/New_dataset/src/postcode_utils.py:20, in load_onsud_from_batch(file)
#      18 def load_onsud_from_batch(file):
#      19     """ from batxh file name (txt) load the onsud chunk"""
# ---> 20     reg = file.split('/')[-2]
#      21     id = file.split('/')[-1].split('.')[0].split('_')[-1]
#      22     onsud = f'/Volumes/T9/postcode_data/data/batches/{reg}/onsud_{id}.csv'
#
# AttributeError: 'NoneType' object has no attribute 'split'

# %%
pcsh  = get_postcode_shapefile(pc)

# %%
pcsh
# Out:
# Empty GeoDataFrame
# Columns: [POSTCODE, UPP, PC_AREA, geometry]
# Index: []

# %%
fig, ax = plt.subplots() 

uprn_match.plot('height', ax=ax, )

uprn_match[uprn_match['upn']==43230338].plot(ax=ax, color='r')
ax.set_title(f'{pc}_Premise Type')
# Out:
# Text(0.5, 1.0, 'N1 2XD_Premise Type')

# %%
pc = 'E10 7NP'

bb = find_batch_from_pc(pc)
ons = load_onsud_from_batch(bb)
pcshp, d = find_postcode_for_ONSUD_file(ons, path_to_pc_shp_folder=pc_shp)
uprn_match = find_data_pc_joint(pc, (d, pcshp), input_gpk=INPUT_GPK)
# Out:
# 208336
# Len of missing rows  0

# %%
uprn_match['premise_type']
# Out:
# 18     Small low terraces
# 20     Small low terraces
# 26     Small low terraces
# 28     Small low terraces
# 106    Small low terraces
#               ...
# 213    Small low terraces
# 215    Small low terraces
# 216    Small low terraces
# 221    Small low terraces
# 222    Small low terraces
# Name: premise_type, Length: 70, dtype: object

# %%
fig, ax = plt.subplots() 

uprn_match.plot('height', ax=ax, label='Small low terraces')

uprn_match[uprn_match['upn']==41948385].plot(ax=ax, color='r')
ax.set_title('Premise Type')
# Out:
# Text(0.5, 1.0, 'Premise Type')

# %%
pc = 'N7 7PH'

bb = find_batch_from_pc(pc)
ons = load_onsud_from_batch(bb)
pcshp, d = find_postcode_for_ONSUD_file(ons, path_to_pc_shp_folder=pc_shp)
uprn_match = find_data_pc_joint(pc, (d, pcshp), input_gpk=INPUT_GPK)
# Out:
# 324023
# Len of missing rows  0

# %%
fig, ax = plt.subplots() 

uprn_match.plot('premise_use', ax=ax )

uprn_match[uprn_match['upn']==43124654].plot(ax=ax, color='r')
# Out:
# <AxesSubplot: >

# %%
pc = 'E5 9HL'

bb = find_batch_from_pc(pc)
ons = load_onsud_from_batch(bb)
pcshp, d = find_postcode_for_ONSUD_file(ons, path_to_pc_shp_folder=pc_shp)
uprn_match = find_data_pc_joint(pc, (d, pcshp), input_gpk=INPUT_GPK)
# Out:
# 382845
# Len of missing rows  0

# %%
pc = 'E7 0NJ'

bb = find_batch_from_pc(pc)
ons = load_onsud_from_batch(bb)
pcshp, d = find_postcode_for_ONSUD_file(ons, path_to_pc_shp_folder=pc_shp)
uprn_match = find_data_pc_joint(pc, (d, pcshp), input_gpk=INPUT_GPK)
# Out:
# 378652
# Len of missing rows  0

# %%
pc= 'EN9 3TX'


bb = find_batch_from_pc(pc)
ons = load_onsud_from_batch(bb)
pcshp, d = find_postcode_for_ONSUD_file(ons, path_to_pc_shp_folder=pc_shp)
uprn_match = find_data_pc_joint(pc, (d, pcshp), input_gpk=INPUT_GPK)
# Out:
# 244291
# Len of missing rows  0

# %%
f, ax = plt.subplots() 

uprn_match.plot('height', ax=ax)
# uprn_match[uprn_match['upn']==23500471].plot(ax=ax, color='r')
# Out:
# <AxesSubplot: >

# %%
uprn_match.groupby('premise_type').height.mean()
# Out:
# premise_type
# 2 storeys terraces with t rear extension    10.45
# 3-4 storey and smaller flats                10.10
# Domestic outbuilding                         3.00
# Large semi detached                         19.60
# Small low terraces                          10.40
# Name: height, dtype: float64

# %%
uprn_match['av_fl_h'] = uprn_match['height'] / uprn_match['premise_floor_count']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/gdal_3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File ~/miniconda3/envs/gdal_3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File ~/miniconda3/envs/gdal_3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# ...

# %%
uprn_match

# %%
fig, ax = plt.subplots() 

uprn_match.plot('height', ax=ax)

# uprn_match[uprn_match['upn']==41925315].plot(ax=ax, color='r')
# Out:
# <AxesSubplot: >

# %%
uprn_match = uprn_match[uprn_match['premise_type']!='Domestic outbuilding'].copy()

# %%
data=uprn_match[uprn_match['uprn_count']!=0].copy()

# %%
fig, ax = plt.subplots() 
data.plot( ax=ax)

# uprn_match[uprn_match['upn'] ==42145012].plot(ax=ax, color='r' )
# Out:
# <AxesSubplot: >

# %%
pdf = get_postcode_shapefile(pc)

# %%
def create_vstreet_lookup(postcode_shapefile_path='/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291', base_dir='/Users/gracecolverd/New_dataset'):
    def run_lk(vstreet_lookup, file):
                # open txt file 
                df= pd.read_csv(file, header=None )
                
                vstreet_lookup = pd.concat([vstreet_lookup, df])
                return vstreet_lookup 
    
    if os.path.isfile('src/mappings/vstreet_lookup.csv'):
        vstreet_lookup = pd.read_csv('data/mappings/vstreet_lookup.csv')
    else:
        vstreet_lookup = pd.DataFrame() 
        for file in glob.glob(os.path.join(postcode_shapefile_path, 'one_letter_pc_code/*/*lookup.txt') ) :
            vstreet_lookup = run_lk(vstreet_lookup, file)
        for file in glob.glob(os.path.join(postcode_shapefile_path, 'two_letter_pc_code/*lookup.txt') ) :
            vstreet_lookup = run_lk(vstreet_lookup, file)
        vstreet_lookup.to_csv(os.path.join(base_dir, 'src/mapping/vstreet_lookup.csv')) 
        
    return vstreet_lookup

# %%
vstreet_lookup = create_vstreet_lookup()

# %%
pc = 'EC1Y 8NE'

# vstreet_lookup[vstreet_lookup[0]==pc ]

vpc = vstreet_lookup[vstreet_lookup[0]==pc][1].values[0]
mpcs = vstreet_lookup[vstreet_lookup[1]==vpc][0].tolist()

# %%
ec = gpd.read_file('/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291/two_letter_pc_code/ec.shp')

# %%
vpc = vstreet_lookup[vstreet_lookup[0]==pc][1].values[0]
mpcs = vstreet_lookup[vstreet_lookup[1]==vpc][0].tolist()  

# ec[ec['POSTCODE'] == vpc ].plot()

total_bounds = ec[ec['POSTCODE'].isin(mpcs+ [vpc] ) ].buffer(100).total_bounds

# %%
vstreet_lookup[vstreet_lookup[0].isin(mpcs)]
# Out:
#             0         1
# 658  EC1Y 8NE  VEC00358
# 659  EC1Y 8NQ  VEC00358

# %%
total_bounds
# Out:
# array([532457., 182189., 532667., 182399.])

# %%
build = gpd.read_file('/Volumes/T9/postcode_data/data/verisk_y2022_V4/bbox_529252.36_186435.25920425786_539252.36_196435.25920425786.gpkg')
# total_bounds = array([532020., 181806., 532230., 182016.])
# total_bounds convert to bounding box 
bbox = box(total_bounds[0], total_bounds[1], total_bounds[2], total_bounds[3])   

# new data 
build = gpd.read_file('/Volumes/T9/Data_downloads/Versik_building_data/2024_03_22_updated_data/UKBuildings_Edition_15_new_format_upn.gpkg', bbox=bbox)   

# build2 = pre_process_building_data(build)

# %%
ec[ec['POSTCODE'].isin(mpcs+ [vpc] ) ]
# Out:
#       POSTCODE                   UPP PC_AREA  \
# 2129  VEC00358  00004000000001753044      EC
#
#                                                geometry
# 2129  POLYGON ((532557.000 182289.000, 532557.000 18...

# %%
gas = pd.read_csv('')
# Out:
# <AxesSubplot: >

# %%
build.sindex.valid_query_predicates
# Out:
# {None,
#  'contains',
#  'contains_properly',
#  'covered_by',
#  'covers',
#  'crosses',
#  'intersects',
#  'overlaps',
#  'touches',
#  'within'}

# %%
fig, ax = plt.subplots() 
ec.sjoin(build).plot(edgecolor='r', facecolor='white', ax=ax)

build.plot('height', ax=ax)

ec[ec['POSTCODE'].isin(mpcs+ [vpc] ) ].plot(ax=ax, edgecolor='red', facecolor='white')

build[build['upn']==43211251].plot(alpha=0.4, color='pink', ax=ax)
# Out:
# <AxesSubplot: >

# %%
build[build['upn']==43211251]
# Out:
# Empty GeoDataFrame
# Columns: [premise_age, premise_year, premise_use, premise_type, premise_floor_count, height, premise_area, building_area, address_area, gross_area, basement, listed_grade, element_count, bathroom_count, bedroom_count, reception_room_count, roof_type, wall_type, substructure_type, glazing_type, wall_construction_type, extension_count, habitable_rooms, open_fireplaces, floor_type, distance_building, site_id, site_area, site_non_built_area, site_building_count, distance_water, verisk_building_id, uprn, uprn_count, uprn_distance, toid, map_age, map_floors, map_use, map_simple_use, upn, geometry]
# Index: []
#
# [0 rows x 42 columns]

# %%
def get_buildings_from_bounds_geofile(geodf, building_file='/Volumes/T9/Data_downloads/Versik_building_data/2024_03_22_updated_data/UKBuildings_Edition_15_new_format_upn.gpkg'   ):
    total_bounds = geodf.total_bounds
    # total_bounds convert to bounding box 
    bbox = box(total_bounds[0], total_bounds[1], total_bounds[2], total_bounds[3])   
    build = gpd.read_file(building_file, bbox=bbox) 
    return build

# %%
vstreet_lookup[vstreet_lookup[0] == 'B7 4QA']
# Out:
# Empty DataFrame
# Columns: [0, 1]
# Index: []

# %%
from src.pre_process_buildings import pre_process_buildings

# %%
d = pre_process_buildings(build)

# %%
build['num_heght'] = pd.to_numeric(build['height'], errors = 'coerce' )

# %%
len(build)
# Out:
# 53

# %%
# def get_postcode_shapefile(pc, path_to_pc_shp_folder= '/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291'):
#     """ find pc shapfile based on the postcode"""
#     # Regex pattern to extract 1 or 2 letters at the beginning of the string followed by a digit
#     pattern = r'^([A-Za-z]{1,2})\d'
    
#     # Using re.search() or re.match() to find the pattern
#     match = re.match(pattern, pc)

#     # Checking if a match was found and extracting the group
#     if match:
#         pc_test= match.group(1)  
#     pc_test= pc_test.lower()
#     if len(pc_test)==1:
#         pc_path =os.path.join(path_to_pc_shp_folder,  f'one_letter_pc_code/{pc_test}/{pc_test}.shp'  )
#         pc_shp = gpd.read_file(pc_path)    
#     else:
#         pc_path =os.path.join(path_to_pc_shp_folder,  f'two_letter_pc_code/{pc_test}.shp' ) 
#         pc_shp = gpd.read_file(pc_path)  

#     return pc_shp[pc_shp['POSTCODE']==pc]

# def find_data_pc_spatialjoin(pc, input_gpk):
#     """
#     Find buildings based on spatial join  
#     """
#     sph = get_postcode_shapefile(pc) 
    
#     bbox = box(*sph.total_bounds)
#     buildings = gpd.read_file(input_gpk, bbox=bbox)
#     uprn_match = buildings.sjoin(sph, how='inner', op='within')
#     return uprn_match

# %%
from src.age_calc import process_postcode_age_residential
from src.age_proc import load_global_average_mode

# %%
pc='LE12 8QD'
premise_dict= load_global_average_mode()
uprn_match = find_data_pc(pc, data, input_gpk=INPUT_GPK)
process_postcode_age_residential(pc, data, INPUT_GPK , premise_dict) 

# uprn_match = find_data_pc(pc, data, input_gpk=INPUT_GPK)
# Out:
# Starting all unknown postcode
# All unknowns but some type
# ('1960-1979', '1960-1979', '1960-1979', '1960-1979', 0, 1, 0.0)
# {'postcode': 'LE12 8QD',
#  'count_unknown_age': nan,
#  'globalfill_median_age': '1960-1979',
#  'globalfill_modal_age': '1960-1979',
#  'globalfill_min_age': '1960-1979',
#  'globalfill_max_age': '1960-1979',
#  'globalfill_range_age': 0,
#  'globalfill_distinct_ages': 1,
#  'globalfill_iqr_age': 0.0,
#  'localfill_median_age': nan,
#  'localfill_modal_age': nan,
#  'localfill_min_age': nan,
#  'localfill_max_age': nan,
#  'localfill_range_age': nan,
#  'localfill_distinct_ages': nan,
#  'localfill_iqr_age': nan}

# %%
uprn_match[['premise_floor_count', 'height', 'premise_type']]
# Out:
#   premise_floor_count     height             premise_type
# 4                   1  34.099998  Tall flats 6-15 storeys

# %%
uprn_match['height'] / uprn_match['premise_floor_count']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/gdal_3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File ~/miniconda3/envs/gdal_3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File ~/miniconda3/envs/gdal_3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# ...

# %%
from src.pre_process_buildings import pre_process_buildings 
from src.age_calc import bucket_age 

uprn_match
df = pre_process_buildings(uprn_match)  
df = bucket_age(df)
if len(df[df['premise_age_bucketed']=='Unknown date']) == len(df):
    print('Starting all unknown postcode')
# Out:
# Starting all unknown postcode

# %%
if len(df[df['premise_type'].isnull()])==len(df):
    print('y')
# Out:
# y

# %%
if len(df[df['premise_type']==None])==len(df):
            print('All unknowns')

# %%
# error in nw 
pc = 'PR25 5QG'

p='/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291'
pc_df , data = find_postcode_for_ONSUD_file('/Volumes/T9/Data_downloads/ONS_UPRN_database/ONSUD_DEC_2022/Data/ONSUD_DEC_2022_NW.csv' , p)

uprn_match34 = find_data_pc(pc, data, input_gpk=INPUT_GPK)
process_postcode_age_residential(pc, data, INPUT_GPK , premise_dict)
# Out:
# /Users/gracecolverd/New_dataset/src/postcode_utils.py:61: DtypeWarning: Columns (25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   ee = pd.read_csv(path_to_onsud_file)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 4
#       1 pc = 'PR25 5QG'
#       3 p='/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291'
# ----> 4 pc_df , data = find_postcode_for_ONSUD_file('/Volumes/T9/Data_downloads/ONS_UPRN_database/ONSUD_DEC_2022/Data/ONSUD_DEC_2022_NW.csv' , p)
#       6 uprn_match34 = find_data_pc(pc, data, input_gpk=INPUT_GPK)
#       7 process_postcode_age_residential(pc, data, INPUT_GPK , premise_dict)
#
# File ~/New_dataset/src/postcode_utils.py:62, in find_postcode_for_ONSUD_file(path_to_onsud_file, path_to_pc_shp_folder)
# ...

# %%
from src.utils import load_pc_shp

# %%
# pc= 'DH9 6PZ'


# p='/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291'
# pc_df , data = find_postcode_for_ONSUD_file('/Volumes/T9/Data_downloads/ONS_UPRN_database/ONSUD_DEC_2022/Data/ONSUD_DEC_2022_NE.csv' , p)

# %%
# pc='NE22 7BR'

# uprn_match = find_data_pc(pc, data, input_gpk=INPUT_GPK)
# d= bucket_age( pre_process_buildings(uprn_match) )

# %%
# pc= 'NE34 8PN'
# uprn_match = find_data_pc(pc, data, input_gpk=INPUT_GPK)
# d= bucket_age( pre_process_buildings(uprn_match) ) 
# # calc_age_attributes((d))

# %%
import pandas as pd 

def load_ids_from_file(file_path):
    with open(file_path, 'r') as file:
        ids = file.read().splitlines()
    return ids

# %%
df = pd.read_csv('/Users/gracecolverd/New_dataset/test/batches/EM/onsud_0.csv') 

ids = load_ids_from_file('/Users/gracecolverd/New_dataset/test/batches/EM/batch_0.txt')
# Out:
# /var/folders/n5/_2d3c5sd5j3810327mknn0sh0000gn/T/ipykernel_12285/1009912072.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/gracecolverd/New_dataset/test/batches/EM/onsud_0.csv')

# %%
df
# Out:
#                 UPRN  GRIDGB1E  GRIDGB1N      PCDS    CTY21CD    CED21CD  \
# 0         3040060399    460318    336422  NG2 6QS   E10000024  E58001216
# 1         3040060405    460586    336884  NG2 6NA   E10000024  E58001202
# 2         3040060409    460093    338051  NG2 5AX   E10000024  E58001202
# 3         3040060419    466833    339102  NG12 2NW  E10000024  E58001202
# 4         3040060420    457511    336398  NG2 7ER   E10000024  E58001217
# ...              ...       ...       ...       ...        ...        ...
# 375414  200003513037    441794    325896       NaN  E10000018  E58000842
# 375415  200004243384    471672    348417       NaN  E10000024  E58001182
# 375416  200004252435    475942    354087       NaN  E10000024  E58001182
# 375417  200004248778    482552    350077       NaN  E10000024  E58001169
# 375418  200004249583    468255    367694       NaN  E10000024  E58001201
#
#           LAD21CD     WD21CD PARNCP20CD   HLTH19CD  ...     WZ11CD    CCG21CD  \
# ...

# %%
len(df)
# Out:
# 317885

# %%
df = pd.read_csv('/Users/gracecolverd/New_dataset/test/batches/EM/onsud_0.csv') 

ids = load_ids_from_file('/Users/gracecolverd/New_dataset/test/batches/EM/batch_0.txt')
d_ids= df['PCDS_strip'].unique().tolist()

# find any not in both d_ids and ids 
for i in ids:
    if i not in d_ids:
        print(i)

# for i in d_ids:
#     if i not in ids:
#         print(i)
# Out:
# /var/folders/n5/_2d3c5sd5j3810327mknn0sh0000gn/T/ipykernel_12285/1058249511.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/gracecolverd/New_dataset/test/batches/EM/onsud_0.csv')

# %%
df[df['PCDS_strip']== 'NG12 2PX' ]
# Out:
#                UPRN  GRIDGB1E  GRIDGB1N      PCDS    CTY21CD    CED21CD  \
# 76       3040060759    467264    338251  NG12 2PX  E10000024  E58001172
# 106793  10025480308    467266    338199  NG12 2PX  E10000024  E58001172
#
#           LAD21CD     WD21CD PARNCP20CD   HLTH19CD  ...    CCG21CD    BUA11CD  \
# 76      E07000176  E05009715  E04007971  E18000004  ...  E38000243  E34999999
# 106793  E07000176  E05009715  E04007971  E18000004  ...  E38000243  E34999999
#
#         BUASD11CD ruc11ind oac11ind   lep21cd1 lep21cd2    pfa21cd imd19ind  \
# 76      E35999999      NaN      NaN  E37000045      NaN  E23000019        0
# 106793  E35999999      NaN      NaN  E37000045      NaN  E23000019        0
#
#        PCDS_strip
# 76       NG12 2PX
# 106793   NG12 2PX
#
# [2 rows x 31 columns]

# %%
if 'NG2 6QS' in d_ids:
    print('y')

# %%
import os 
p = '/Users/gracecolverd/New_dataset/test/batches/EM/batch_0.txt'
os.path.basename(p) 
batch_id  =0 
os.path.join(os.path.dirname(p), f'onsud_{batch_id}.csv')
# Out:
# '/Users/gracecolverd/New_dataset/test/batches/EM/onsud_0.csv'

# %%
path_to_pc_shp_folder='/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291'
ee= df.copy() 
ee['leading_letter'] = ee['PCDS'].str.extract(r'^([A-Za-z]{1,2})\d')
ee= ee[~ee['PCDS'].isna() ] 
ee['PCDS'] = ee['PCDS'].str.strip()

whole_pc= []
for pc in ee['leading_letter'].unique():
    pc= pc.lower()
    if len(pc)==1:
        pc_path =os.path.join(path_to_pc_shp_folder,  f'one_letter_pc_code/{pc}/{pc}.shp'  )
        pc_shp = gpd.read_file(pc_path)    
    else:
        pc_path =os.path.join(path_to_pc_shp_folder,  f'two_letter_pc_code/{pc}.shp' ) 
        pc_shp = gpd.read_file(pc_path)    
    whole_pc.append(pc_shp)

pc_df = pd.concat(whole_pc)

# %%
pc_df[pc_df['POSTCODE']==  'NG12 2PX']
# Out:
# Empty GeoDataFrame
# Columns: [POSTCODE, UPP, PC_AREA, geometry]
# Index: []

# %%
df= pd.read_csv('/Users/gracecolverd/New_dataset/test/proc_dir/fuel/EM/0_log_file.csv') 

df2 =pd.read_csv('/Users/gracecolverd/New_dataset/test/proc_dir/fuel/EM_old/0_log_file.csv')

d = df.merge(df2, on='postcode')
d=d[~d['all_types_build_vol_FGA_total_x'].isna() ]
d[d['all_types_build_vol_FGA_total_x'] !=d['all_types_build_vol_FGA_total_y']]

# %%
glob.glob('/home/gb669/rds/hpc-work/energy_map/data/batches/*/*.txt')
# Out:
# Empty DataFrame
# ...

# %%
import sys 
sys.path.append('/Users/gracecolverd/New_dataset/src' )

from src.overlap import custom_load_onsud
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[75], line 4
#       1 import sys
#       2 sys.path.append('/Users/gracecolverd/New_dataset/src' )
# ----> 4 from src.overlap import custom_load_onsud
#
# ModuleNotFoundError: No module named 'src.overlap'

# %%
pc= 'PE9 3JQ'

df = custom_load_onsud()

# %%
p='/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291'
pc_df , data = find_postcode_for_ONSUD_file('/Volumes/T9/Data_downloads/ONS_UPRN_database/ONSUD_DEC_2022/Data/ONSUD_DEC_2022_NE.csv' , p)
# Out:
# /Users/gracecolverd/New_dataset/src/postcode_utils.py:61: DtypeWarning: Columns (25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   ee = pd.read_csv(path_to_onsud_file)
# Len of missing rows  0

# %%
from src.age_calc import process_postcode_age_residential 
from src.age_proc import load_global_average_mode

# %%
uprn_match = find_data_pc(pc, data, input_gpk=INPUT_GPK)

# %%
premise_dict= load_global_average_mode()
pc = 'DL5 4DG' 
process_postcode_age_residential(pc, data, INPUT_GPK , premise_dict)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# Name: loc_ordinal, dtype: float64
# /Users/gracecolverd/miniconda3/envs/gdal_3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 premise_dict= load_global_average_mode()
#       2 pc = 'DL5 4DG'
# ----> 3 process_postcode_age_residential(pc, data, INPUT_GPK , premise_dict)
#
# File ~/New_dataset/src/age_calc.py:174, in process_postcode_age_residential(pc, data, INPUT_GPK, premise_dict)
#     172     dicc = all_unknowns(df)
#     173 else:
# --> 174     dicc= normal_df(df)
#     177 dc_full.update(dicc )
#     179 return dc_full
#
# ...

# %%
import numpy as np

# %%
df= pd.read_csv('/Users/gracecolverd/New_dataset/test/proc_dir/fuel/NE/fuel/0_log_file.csv')
len(df)
# Out:
# 970

# %%
if df.groupby('postcode').size().max() >1:
    print('Duplicate postcodes found in the batch')

# %%
def all_unknowns(df):
    return None 


def deal_nans(df, premise_dict ):
    if len(df)==1:
       results = one_df(df)
       return results 
    if len(df[df['premise_age']=='Unknown date']) ==len(df):
        results = all_unknowns(df)
        return results
    df['loc_fill_age'] = np.where(df['premise_age_bucketed'] == 'Unknown date', df['premise_age_bucketed'].mode()[0], df['premise_age_bucketed'])
    df['global_fill_age'] = np.where(df['premise_age_bucketed'] == 'Unknown date', df['premise_type'].map(premise_dict), df['premise_age_bucketed'])
    df['loc_ordinal'] = df['loc_fill_age'].map(category_to_ordinal)
    df['global_ordinal'] = df['global_fill_age'].map(category_to_ordinal)
# Out:
# Only one building
# Unknown date and none type
# (nan, nan, 'Unknown date', 'Unknown date', 'Unknown date', 0, 1, nan, nan)

# %%
d['premise_age_bucketed'] =['Unknown date' for i in range(len(d))]

# %%
 
def load_global_average_mode():
    """ Load global average data """
    global_av = pd.read_csv('/Users/gracecolverd/New_dataset/global_averages/global_Average_age_df_mode.csv')
    global_av =  bucket_age(global_av)    
    premise_dict = {}

    for i, row in global_av.iterrows():
        premise_type = row['premise_type']
        premise_age_bucketed = row['premise_age_bucketed']

        if premise_type not in premise_dict:
            premise_dict[premise_type] = {}
        
        premise_dict[premise_type] = premise_age_bucketed
    return premise_dict

# %%
premise_dict = load_global_average_mode() 


np.where(d['premise_age_bucketed'] == 'Unknown date', d['premise_type'].map(premise_dict), d['premise_age_bucketed'])
# Out:
# array(['1960-1979', '1960-1979', '1960-1979', '1960-1979', '1960-1979',
#        '1960-1979', '1960-1979', '1960-1979', '1960-1979', '1960-1979',
#        '1960-1979', '1960-1979', '1960-1979', '1960-1979', '1960-1979'],
#       dtype=object)

# %%
premise_dict
# Out:
# {'2 storeys terraces with t rear extension': 'Pre 1919',
#  '3-4 storey and smaller flats': '1960-1979',
#  'Large detached': 'Post 1999',
#  'Large semi detached': 'Pre 1919',
#  'Linked and step linked premises': '1960-1979',
#  'Medium height flats 5-6 storeys': 'Post 1999',
#  'Planned balanced mixed estates': '1960-1979',
#  'Semi type house in multiples': '1919-1944',
#  'Small low terraces': 'Pre 1919',
#  'Standard size detached': '1960-1979',
#  'Standard size semi detached': '1919-1944',
#  'Tall flats 6-15 storeys': '1960-1979',
#  'Tall terraces 3-4 storeys': 'Pre 1919',
#  'Very large detached': 'Pre 1919',
#  'Very tall point block flats': '1960-1979'}

# %%
# BEGIN: create dictionary indexed by premise use and premise type , with value premise-age-bucketed
premise_dict = {}

for i, row in global_df.iterrows():
    
    premise_type = row['premise_type']
    premise_age_bucketed = row['premise_age_bucketed']
    
    if premise_type not in premise_dict:
        premise_dict[premise_type] = {}
    
    premise_dict[premise_type] = premise_age_bucketed

premise_dict
# END: create dictionary indexed by premise use and premise type , with value premise-age-bucketed
# create dictionary indexed by premise use and premise type , with value premise-age-bucketed
# Out:
# {'2 storeys terraces with t rear extension': 'Pre 1919',
#  '3-4 storey and smaller flats': '1960-1979',
#  'Large detached': 'Post 1999',
#  'Large semi detached': 'Pre 1919',
#  'Linked and step linked premises': '1960-1979',
#  'Medium height flats 5-6 storeys': 'Post 1999',
#  'Planned balanced mixed estates': '1960-1979',
#  'Semi type house in multiples': '1919-1944',
#  'Small low terraces': 'Pre 1919',
#  'Standard size detached': '1960-1979',
#  'Standard size semi detached': '1919-1944',
#  'Tall flats 6-15 storeys': '1960-1979',
#  'Tall terraces 3-4 storeys': 'Pre 1919',
#  'Very large detached': 'Pre 1919',
#  'Very tall point block flats': '1960-1979'}

# %%
  if len(df[df['premise_age']=='Unknown date']) == len(df):
            if len( df[df['premise_type']==None]) ==len(df):
                print('All unknown dates and none types')
                return np.nan, np.nan, age, age, age, np.nan, np.nan, np.nan, np.nan  
            else: 
                df = df.merge(global_df, on=['premise_use', 'premise_type']).rename(columns={'premise_age_bucketed_y':'premise_age_bucketed', 'ordinal_age_y':'ordinal_age'})
                return np.nan, np.nan, age, age, age, 0, 1, np.nan, np.nan
    deal_nans(df)

# %%
d
# Out:
#     premise_age premise_year  premise_use premise_type premise_floor_count  \
# 0  Unknown date         None  Residential         None                   2
#
#    height  premise_area  building_area  address_area  gross_area  ...  \
# 0     9.2         151.0          151.0         302.0       302.0  ...
#
#   height_numeric floor_count_numeric  height_bucket  floor_count_numeric_FGA  \
# 0            9.2                   2          9-10m                      2.0
#
#    floor_count_element_av  floor_count_element_av_FGA height_numeric_FGA  \
# 0                     2.0                         2.0                9.2
#
#   listed_bool premise_age_bucketed ordinal_age
# 0           0         Unknown date         NaN
#
# [1 rows x 52 columns]

# %%
uprn_match

from src.age_calc import calc_age_attributes , bucket_age
from src.pre_process_buildings import pre_process_buildings 

d= pre_process_buildings(uprn_match)
calc_age_attributes(bucket_age(d))
# Out:
# ('1919-1944',
#  '1919-1944',
#  '1919-1944',
#  '1919-1944',
#  '1919-1944',
#  0.0,
#  1,
#  0.0,
#  0.0)

# %%
def load_global_average_mode():
    """ Load global average data """
    global_av = pd.read_csv('/Users/gracecolverd/New_dataset/global_averages/global_Average_age_df_mode.csv')
    return global_av

glo = load_global_average_mode()
glo = bucket_age(glo)

# %%
d
# Out:
#     premise_age  premise_year  premise_use premise_type premise_floor_count  \
# 0  Unknown date           NaN  Residential         None                   2
# 1     1919-1944           NaN  Educational         None                None
# 2     1919-1944           NaN  Educational         None                None
#
#       height  premise_area  building_area  address_area   gross_area  ...  \
# 0   9.200000    653.099976    3391.399902   1306.199951  1306.199951  ...
# 1  17.799999   1155.000000    1155.000000           NaN          NaN  ...
# 2   9.400000   1129.300049    1129.300049           NaN          NaN  ...
#
#   premise_age_bucketed ordinal_age  height_numeric  floor_count_numeric  \
# 0            1919-1944         NaN        9.200000                  2.0
# 1            1919-1944         1.0       17.799999                  NaN
# 2            1919-1944         1.0        9.400000                  NaN
#
#    height_bucket  floor_count_numeric_FGA floor_count_element_av  \
# ...

# %%
d.merge(glo, on=['premise_use', 'premise_type'])
# Out:
# Empty GeoDataFrame
# Columns: [premise_age_x, premise_year, premise_use, premise_type, premise_floor_count, height, premise_area, building_area, address_area, gross_area, basement, listed_grade, element_count, bathroom_count, bedroom_count, reception_room_count, roof_type, wall_type, substructure_type, glazing_type, wall_construction_type, extension_count, habitable_rooms, open_fireplaces, floor_type, distance_building, site_id, site_area, site_non_built_area, site_building_count, distance_water, verisk_building_id, uprn, uprn_count, uprn_distance, toid, map_age, map_floors, map_use, map_simple_use, upn, geometry, premise_age_bucketed_x, ordinal_age_x, height_numeric, floor_count_numeric, height_bucket, floor_count_numeric_FGA, floor_count_element_av, floor_count_element_av_FGA, height_numeric_FGA, listed_bool, premise_age_y, count, premise_age_bucketed_y, ordinal_age_y]
# Index: []
#
# [0 rows x 56 columns]

# %%
if len(d[d['premise_use']=='Residential']) != len(d):
 print('e')
# Out:
# e

# %%
dd = load_pc_shp(['S'])

# %%
f, ax = plt.subplots()
pc='S17 4GJ'
dd[dd['POSTCODE']== pc ].plot(ax=ax, edgecolor='k', facecolor='none', label='S17 4GJ Outline')
uprn_match2.plot(ax=ax,color='r',  label = 'All building footprints matched')

legend_elements = [Line2D([0], [0], color='k', lw=1, label='Postcode S17 4HA'),
                   Patch([0], [0], color='r', lw=2, label='Building Footprints')]
ax.legend(handles=legend_elements, loc='upper right') 

# remove axes 
ax.set_axis_off()

# add border around whole image 
plt.gca().add_artist(plt.Rectangle((0,0),1,1, fill=False, edgecolor='black', lw=2))
# Out:
# /var/folders/n5/_2d3c5sd5j3810327mknn0sh0000gn/T/ipykernel_38455/3479114521.py:7: MatplotlibDeprecationWarning: Passing the edgecolor parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   Patch([0], [0], color='r', lw=2, label='Building Footprints')]
# /var/folders/n5/_2d3c5sd5j3810327mknn0sh0000gn/T/ipykernel_38455/3479114521.py:7: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   Patch([0], [0], color='r', lw=2, label='Building Footprints')]

# %%
p='/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291'
pc_df , dat_Em = find_postcode_for_ONSUD_file('/Volumes/T9/Data_downloads/ONS_UPRN_database/ONSUD_DEC_2022/Data/ONSUD_DEC_2022_EE.csv' , p)
# Out:
# Len of missing rows  0

# %%
GAS_PATH='/Volumes/T9/Data_downloads/UKGOV_Gas_elec/Postcode_level_gas_2022.csv'
ELEC_PATH='/Volumes/T9/Data_downloads/UKGOV_Gas_elec/Postcode_level_all_meters_electricity_2022.csv'
gas_df = pd.read_csv(GAS_PATH)  
elec_df = pd.read_csv(ELEC_PATH)

# %%
pc= 'S17 4HA' 

uprn_match = find_data_pc(pc, data, input_gpk=INPUT_GPK)

# %%
from src.fuel_calc import process_postcode_fuel
p='/Volumes/T9/Data_downloads/codepoint_polygons_edina/Download_all_postcodes_2378998/codepoint-poly_5267291'
pc_df , dat_Em = find_postcode_for_ONSUD_file('/Volumes/T9/Data_downloads/ONS_UPRN_database/ONSUD_DEC_2022/Data/ONSUD_DEC_2022_EM.csv' , p)
# Out:
# /Users/gracecolverd/New_dataset/src/postcode_utils.py:61: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   ee = pd.read_csv(path_to_onsud_file)
# Len of missing rows  0

# %%
pc_df , dat_yh = find_postcode_for_ONSUD_file('/Volumes/T9/Data_downloads/ONS_UPRN_database/ONSUD_DEC_2022/Data/ONSUD_DEC_2022_yh.csv' , p)
# Out:
# Len of missing rows  0

# %%
pc='S81 9JP' 
up_yh = find_data_pc(pc, dat_yh, input_gpk=INPUT_GPK)     

process_postcode_fuel(pc, dat_yh, gas_df, elec_df, INPUT_GPK )
# Out:
# S81 9JP
# len df  2
# {'postcode': 'S81 9JP',
#  'num_invalid_builds': 0,
#  'all_types_total_buildings': 2,
#  'all_types_build_vol_FGA_total': 2486.430041999818,
#  'all_types_base_floor_total': 0,
#  'all_types_build_vol_inc_basement_FGA_total': 2486.430041999818,
#  'all_types_heated_vol_EA_FGA_total': 1324.7999999999997,
#  'all_types_heated_vol_FGA_total': 1324.7999999999997,
#  'all_types_heated_vol_inc_basement_EA_FGA_total': 1324.7999999999997,
#  'all_types_heated_vol_inc_basement_FGA_total': 1324.7999999999997,
#  'all_types_listed_bool_total': 0,
#  'all_types_uprn_count_total': 6,
#  'res_total_buildings': 2,
#  'res_build_vol_FGA_total': 2486.430041999818,
#  'res_base_floor_total': 0,
#  'res_build_vol_inc_basement_FGA_total': 2486.430041999818,
#  'res_heated_vol_EA_FGA_total': 1324.7999999999997,
#  'res_heated_vol_FGA_total': 1324.7999999999997,
#  'res_heated_vol_inc_basement_EA_FGA_total': 1324.7999999999997,
# ...

# %%
pc='S81 9JP' 
up_em = find_data_pc(pc, dat_Em, input_gpk=INPUT_GPK)     

process_postcode_fuel(pc, dat_Em, gas_df, elec_df, INPUT_GPK )
# Out:
# S81 9JP
# len df  44
# {'postcode': 'S81 9JP',
#  'num_invalid_builds': 0,
#  'all_types_total_buildings': 44,
#  'all_types_build_vol_FGA_total': 40761.12956907273,
#  'all_types_base_floor_total': 0,
#  'all_types_build_vol_inc_basement_FGA_total': 40761.12956907273,
#  'all_types_heated_vol_EA_FGA_total': 21526.505162262354,
#  'all_types_heated_vol_FGA_total': 21526.505162262354,
#  'all_types_heated_vol_inc_basement_EA_FGA_total': 21526.505162262354,
#  'all_types_heated_vol_inc_basement_FGA_total': 21526.505162262354,
#  'all_types_listed_bool_total': 0,
#  'all_types_uprn_count_total': 85,
#  'res_total_buildings': 43,
#  'res_build_vol_FGA_total': 40350.93953767777,
#  'res_base_floor_total': 0,
#  'res_build_vol_inc_basement_FGA_total': 40350.93953767777,
#  'res_heated_vol_EA_FGA_total': 21424.039796447752,
#  'res_heated_vol_FGA_total': 21424.039796447752,
#  'res_heated_vol_inc_basement_EA_FGA_total': 21424.039796447752,
# ...

# %%
fig, ax = plt.subplots() 
up_em.plot(ax=ax)
up_yh.plot(ax=ax, color='r')
# Out:
# <AxesSubplot: >
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def load_ids_from_file(file_path):
    with open(file_path, 'r') as file:
        ids = file.read().splitlines()
    return ids

# %%
# next hihest 
from src.fuel_calc import process_postcode_fuel 

pc='S81 9JP' 


GAS_PATH='/Volumes/T9/Data_downloads/UKGOV_Gas_elec/Postcode_level_gas_2022.csv'
ELEC_PATH='/Volumes/T9/Data_downloads/UKGOV_Gas_elec/Postcode_level_all_meters_electricity_2022.csv'
gas_df = pd.read_csv(GAS_PATH)  
elec_df = pd.read_csv(ELEC_PATH)

process_postcode_fuel(pc,dat_Em ,gas_df, elec_df, INPUT_GPK=INPUT_GPK)    

#
# 
# high meter postcodes 
# 31292    84.0
# 30954    49.0
# Out:
# /Users/gracecolverd/New_dataset/src/postcode_utils.py:61: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   ee = pd.read_csv(path_to_onsud_file)
# Len of missing rows  0
# S81 9JP
# len df  44
# {'postcode': 'S81 9JP',
#  'num_invalid_builds': 0,
#  'all_types_total_buildings': 44,
#  'all_types_build_vol_FGA_total': 40761.12956907273,
#  'all_types_base_floor_total': 0,
#  'all_types_build_vol_inc_basement_FGA_total': 40761.12956907273,
#  'all_types_heated_vol_EA_FGA_total': 21526.505162262354,
#  'all_types_heated_vol_FGA_total': 21526.505162262354,
#  'all_types_heated_vol_inc_basement_EA_FGA_total': 21526.505162262354,
#  'all_types_heated_vol_inc_basement_FGA_total': 21526.505162262354,
#  'all_types_listed_bool_total': 0,
#  'all_types_uprn_count_total': 85,
#  'res_total_buildings': 43,
#  'res_build_vol_FGA_total': 40350.93953767777,
#  'res_base_floor_total': 0,
# ...

# %%
fold = glob.glob('/Users/gracecolverd/New_dataset/test/batches/EM/*.txt' ) 

for f in fold:
    # load txt
    file = load_ids_from_file(f) 
    if pc in file:
        print(f)
        print('y')
# Out:
# /Users/gracecolverd/New_dataset/test/batches/EM/batch_7.txt
# y

# %%
up.columns

# up.uprn_count.sum()
# Out:
# Index(['premise_age', 'premise_year', 'premise_use', 'premise_type',
#        'premise_floor_count', 'height', 'premise_area', 'building_area',
#        'address_area', 'gross_area', 'basement', 'listed_grade',
#        'element_count', 'bathroom_count', 'bedroom_count',
#        'reception_room_count', 'roof_type', 'wall_type', 'substructure_type',
#        'glazing_type', 'wall_construction_type', 'extension_count',
#        'habitable_rooms', 'open_fireplaces', 'floor_type', 'distance_building',
#        'site_id', 'site_area', 'site_non_built_area', 'site_building_count',
#        'distance_water', 'verisk_building_id', 'uprn', 'uprn_count',
#        'uprn_distance', 'toid', 'map_age', 'map_floors', 'map_use',
#        'map_simple_use', 'upn', 'geometry'],
#       dtype='object')

# %%
gas_df =

# %%
up.building_area.sum()
# Out:
# 4825.899955749512

# %%
up.plot()
# Out:
# <AxesSubplot: >

# %%
up['']

# %%
pc= 'CM18 6SD'
# Out:
#      premise_age premise_year  premise_use                 premise_type  \
# 13     1960-1979         None  Residential           Small low terraces
# 14     1960-1979         None  Residential               Large detached
# 15     1960-1979         None  Residential  Standard size semi detached
# 16     1960-1979         None  Residential  Standard size semi detached
# 17     1960-1979         None  Residential           Small low terraces
# 18     1960-1979         None  Residential       Standard size detached
# 19     1960-1979         None  Residential  Standard size semi detached
# 20     1960-1979         None  Residential  Standard size semi detached
# 21     1960-1979         None  Residential  Standard size semi detached
# 22     1960-1979         None  Residential  Standard size semi detached
# 23     1960-1979         None  Residential           Small low terraces
# 24     1960-1979         None  Residential  Standard size semi detached
# ...

# %%
find_data_pc
# Out:
# <function src.postcode_utils.find_data_pc(pc, data, input_gpk='/Volumes/T9/Data_downloads/Versik_building_data/2024_03_full_building_data/6101/Data/new_verisk_2022.gpkg')>

# %%
import matplotlib.pyplot as plt 
plt.style.use("seaborn-dark-palette")


f, ax = plt.subplots()
uprn_match.plot(ax=ax, color='b' )
uprn_match2.plot(ax=ax,color='r',  label = 'S17 4GJ')

ax.legend() 
# ax.title('Building footprints for S17 4HA and S17 4GJ')

# create custom legend with patches 
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
legend_elements = [Patch([0], [0], color='b', lw=4, label='S17 4HA'),
                   Patch([0], [0], color='r', lw=4, label='S17 4GJ')]
ax.legend(handles=legend_elements, loc='lower right') 

ax.title.set_text('Building footprints for postcodes') 

# label x axis 
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
# Out:
# /var/folders/n5/_2d3c5sd5j3810327mknn0sh0000gn/T/ipykernel_38455/3456916608.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-dark-palette")
# /var/folders/n5/_2d3c5sd5j3810327mknn0sh0000gn/T/ipykernel_38455/3456916608.py:9: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend()
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
pc='S17 4GJ'
INPUT_GPK='/Volumes/T9/Data_downloads/Versik_building_data/2024_03_22_updated_data/UKBuildings_Edition_15_new_format_upn.gpkg'

# data[data['postcode']==pc]

uprn_match2 = find_data_pc(pc, data, input_gpk=INPUT_GPK)

# %%
# Out:
# <AxesSubplot: >

# %%
df = pd.read_csv('/Users/gracecolverd/New_dataset/test/proc_dir/NE/age/0_log_file.csv')

# %%
df.count_unknown_age.unique()
# Out:
# array([ 0., nan,  1.])

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       postcode  count_unknown_age ignorefill_median_age modalfill_median_age  \
# 0     TS24 8NG                0.0             1945-1959            1945-1959
# 1     TS25 4PY                0.0             1960-1979            1960-1979
# 2     TS25 3DL                0.0             1960-1979            1960-1979
# 3     TS25 3DJ                0.0             1980-1989            1980-1989
# 4     TS26 9BP                0.0             1945-1959            1945-1959
# ...        ...                ...                   ...                  ...
# 7525   SR3 1RQ                0.0             1945-1959            1945-1959
# 7526   SR3 1QY                0.0             1945-1959            1945-1959
# 7527  NE38 0ES                0.0             1960-1979            1960-1979
# 7528   SR3 1QR                0.0             1945-1959            1945-1959
# 7529  NE37 1EX                NaN                   NaN                  NaN
#
# ...

# %%
pc = 'TS25 3DN' 


process_postcode_age(pc, data, INPUT_GPK)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# /Users/gracecolverd/miniconda3/envs/gdal_3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Traceback (most recent call last):
#   File "/Users/gracecolverd/miniconda3/envs/gdal_3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3433, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/n5/_2d3c5sd5j3810327mknn0sh0000gn/T/ipykernel_6489/2488760463.py", line 4, in <module>
#     process_postcode_age(pc, data, INPUT_GPK)
#   File "/Users/gracecolverd/New_dataset/src/age_calc.py", line 118, in process_postcode_age
#   File "/Users/gracecolverd/New_dataset/src/age_calc.py", line 97, in calc_age_attributes
#   File "/Users/gracecolverd/New_dataset/src/age_calc.py", line 85, in calculate_median_age_band
#     ignore_median = np.nan
#
# ...

# %%
df[df['postcode']=='TS3 8QQ']
# Out:
#   postcode  count_unknown_age ignorefill_median_age modalfill_median_age  \
# 0  TS3 8QQ                  0             1960-1979            1960-1979
#
#    modal_age    min_age    max_age  range_age  distinct_ages  \
# 0  1960-1979  1960-1979  1960-1979        0.0              1
#
#    ignorefill_iqr_age  modalfill_iqr_age
# 0                 0.0                0.0

# %%
df[df['count_unknown_age']==1]
# Out:
#      postcode  count_unknown_age ignorefill_median_age modalfill_median_age  \
# 71   TS25 2EN                  1              Pre 1919             Pre 1919
# 201  TS25 2EN                  1              Pre 1919             Pre 1919
# 811  TS25 2EN                  1              Pre 1919             Pre 1919
#
#     modal_age   min_age    max_age  range_age  distinct_ages  \
# 71   Pre 1919  Pre 1919  1960-1979        3.0              4
# 201  Pre 1919  Pre 1919  1960-1979        3.0              4
# 811  Pre 1919  Pre 1919  1960-1979        3.0              4
#
#      ignorefill_iqr_age  modalfill_iqr_age
# 71                  1.0                1.0
# 201                 1.0                1.0
# 811                 1.0                1.0

# %%
import pandas as pd
import numpy as np
import os
from unittest.mock import Mock

# Mock data
data = pd.DataFrame({
    'postcode': ['AB10', 'AB11', 'AB12', 'UNKNOWN', 'AB14', 'UNKNOWN', 'AB16', 'UNKNOWN', 'AB18'],
    'age': [25, 35, np.nan, np.nan, 45, np.nan, 55, np.nan, 65]
})

pcs_list = ['AB10', 'AB11', 'AB12', 'UNKNOWN', 'AB14', 'UNKNOWN', 'AB16', 'UNKNOWN', 'AB18']
INPUT_GPK = 'input_file.gpkg'  # Mock input GPK file
temp_dir = './temp'  # Temporary directory for logs
batch_size = 3
batch_label = 'test_batch'

# Mock implementation of process_postcode_age function
def mock_process_postcode_age(pc, data, INPUT_GPK):
    age_info = data[data['postcode'] == pc]
    if not age_info.empty and not pd.isnull(age_info['age'].values[0]):
        return {'postcode': pc, 'age': age_info['age'].values[0]}
    else:
        # Simulate "ignore fill" strategy for UNKNOWN postcodes
        if pc == 'UNKNOWN':
            return None
        # Simulate "modal fill" strategy by returning a placeholder value
        return {'postcode': pc, 'age': 50}  # Example modal age

# Replace the real function with the mock
process_postcode_age = Mock(side_effect=mock_process_postcode_age)

# %%
from src.age_calc import calc_age_attributes
# Call the function to process the mock data
calc_age_attributes(pcs_list, data, INPUT_GPK, temp_dir, batch_size, batch_label)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[150], line 3
#       1 from src.age_calc import calc_age_attributes
#       2 # Call the function to process the mock data
# ----> 3 calc_age_attributes(pcs_list, data, INPUT_GPK, temp_dir, batch_size, batch_label)
#
# TypeError: calc_age_attributes() takes 1 positional argument but 6 were given

# %%
uprn_match = find_data_pc(pc, data, input_gpk=INPUT_GPK)

# %%
uprn_match
# Out:
#            premise_age premise_year                  premise_use premise_type  \
# 0  1945-1959,1980-1989         None  Institutional accommodation         None
#
#   premise_floor_count  height  premise_area  building_area  address_area  \
# 0               1,2,3    12.2   2052.399902    2052.399902    133.899994
#
#     gross_area  ...          uprn uprn_count  uprn_distance  \
# 0  6157.200195  ...  100110003245         46            0.0
#
#                 toid      map_age      map_floors  \
# 0  osgb1000031181249  Complex age  Complex floors
#
#                        map_use   map_simple_use       upn  \
# 0  Institutional accommodation  Non Residential  21507942
#
#                                             geometry
# 0  MULTIPOLYGON (((450106.205 529816.318, 450105....
#
# [1 rows x 42 columns]

# %%
import numpy as np

# %%
uprn_match
category_order = [  'Pre 1919',
                    '1919-1944',
                    '1945-1959', 
                    '1960-1979',
                    '1980-1989',
                    '1990-1999',
                    'Post 1999' 
                    ]
category_to_ordinal = {category: i for i, category in enumerate(category_order)}
df = bucket_age(uprn_match)

# %%
df['ordinal_age'] = df['premise_age_bucketed'].map(category_to_ordinal)

# %%
df
# Out:
#    premise_age  premise_year  premise_use                    premise_type  \
# 10   1960-1979           NaN  Residential  Planned balanced mixed estates
# 11   1960-1979           NaN  Residential  Planned balanced mixed estates
# 12   1960-1979           NaN  Residential  Planned balanced mixed estates
# 13   1960-1979           NaN  Residential  Planned balanced mixed estates
# 14   1990-1999        1995.0  Residential  Planned balanced mixed estates
# 15   1960-1979           NaN  Residential  Planned balanced mixed estates
# 16   1960-1979           NaN  Residential  Planned balanced mixed estates
# 17   1960-1979           NaN  Residential  Planned balanced mixed estates
# 18   1960-1979           NaN  Residential  Planned balanced mixed estates
# 19   1960-1979           NaN  Residential  Planned balanced mixed estates
# 20   1960-1979           NaN  Residential  Planned balanced mixed estates
# 21   1960-1979           NaN  Residential  Planned balanced mixed estates
# ...

# %%
# def update_split_floor(df):
onsud_dir= '/Volumes/T9/Data_downloads/ONS_UPRN_database/ONSUD_DEC_2022'
date = onsud_dir.split('/')[-1].split('ONSUD_')[-1]
# .split('ONSUD_')[0]
date
# Out:
# 'DEC_2022'

# %%
# replace for each iict 
def replace_multi_level(df):
    mapping = {'1,2' : 1.5, '2,3': 2.5 , '1,3': 2, '3,4': 3.5, '2,4': 3 , '2,5' : 3.5, '2,3,4' : 3, ',Undetermined' : '' }

    # df['premise_floor_int'] = df['premise_floor_count'].# Use the replace method with the mapping
    df['premise_floor_int'] = df['premise_floor_count'].replace(mapping)
    return df

# %%
# df.premise_floor_int.value_counts() 
date = onsud_dir.split('/')[-1].split('ONSUD_')[0]

# %%
# df.iloc[0:1].premise_floor_count.values[0]

# %%
# res_use_types = ['Residential',  'Residential with retail below', 'Retail below office or residential' ] 

# def calc_residential_fuel( df, total_fuel):
#     df = fill_premise_floor_types(df)
#     res = df[df['premise_use']=='Residential'].copy() 
#     perc_res = len(res) / len(df)
#     expanded_res = df[df['premise_use'].isin(res_use_types)].copy() 
#     perc_expanded_res = len(expanded_res) / len(df)

#     if total_fuel is None:
#         res_gas_per_vol, res_gas_per_vol_basement, exp_res_fuel_per_vol, exp_res_fuel_per_vol_basement = -999, -999, -999, -999 
#         return  perc_res, res_gas_per_vol, res_gas_per_vol_basement,  perc_expanded_res, exp_res_fuel_per_vol, exp_res_fuel_per_vol_basement, 
    
#     res_gas_per_vol , res_gas_per_vol_basement =  calc_fuel_metric(res, total_fuel)

#     if perc_res ==1: 
#         exp_res_fuel_per_vol , exp_res_fuel_per_vol_basement  = res_gas_per_vol , res_gas_per_vol_basement 
#     else:
#         exp_res_fuel_per_vol , exp_res_fuel_per_vol_basement = calc_fuel_metric(expanded_res, total_fuel)
    
    
#     return perc_res, res_gas_per_vol, res_gas_per_vol_basement,  perc_expanded_res, exp_res_fuel_per_vol, exp_res_fuel_per_vol_basement, 


# def calc_fuel_metric(df, total_fuel):
#     df['build_vol'] = df['premise_area'] * df['height']
#     total_build_volume = df['build_vol'].sum()
    
#     df['base_floor'] = df['basement'].apply(lambda x: 1 if x in ['Basement confirmed', 'Basement likely'] else 0)
#     total_build_volume_inc_basement = (df['build_vol'] + 2.3 * df['base_floor'] * df['premise_area']).sum()
    
#     df['heated_vol'] = df['premise_area'] * df['premise_floor_count'].astype(int) * 2.3
#     df['heated_vol_inc_basement'] = df['heated_vol'] + 2.3 * df['base_floor'] * df['premise_area']
#     total_heated_volume = df['heated_vol'].sum()

#     total_heated_volume_inc_basement = df['heated_vol_inc_basement'].sum()
    
#     gas_per_heated_vol = total_heated_volume / total_fuel 
#     gas_per_heated_vol_inc_basemeent = total_heated_volume_inc_basement / total_fuel 

#     return  gas_per_heated_vol, gas_per_heated_vol_inc_basemeent 



# def postcode_fuel_vars_batch_fn(pc, data, merge_fuel):
#     input_gpk= '/Volumes/T9/Data_downloads/Versik_building_data/2024_03_full_building_data/6101/Data/new_verisk_2022.gpkg'

#     fuel = merge_fuel[merge_fuel['Postcode']==pc ]
#     if len(fuel)==0:
#         total_fuel = None 
#     total_fuel = fuel['Total_cons_kwh'].values[0]

#     uprn_match = find_data_pc(pc, data, input_gpk=input_gpk)
#     if uprn_match.empty:
#         return pc, 'Completed', 'No buildings found'  
    
#     attr_value = calc_residential_fuel(uprn_match, total_fuel )
    
#     return pc, 'Completed', attr_value

# %%
# import geopandas as gpd
# import glob 
# import pandas as pd
# import os
# import concurrent.futures
# from osgeo import ogr
# import pandas as pd
# import os
# import shutil 
# import tempfile
# import threading


# thread_local = threading.local()


# def run_batching(whole_batch_list, batch_fn, data, result_cols, log_file, batch_size, max_workers, merge_fuel ):
#     with concurrent.futures.ThreadPoolExecutor(max_workers = max_workers ) as executor:
#         # Store futures if you need to wait for them or check for exceptions
#         futures = []
#         for i in range(0, len(whole_batch_list), batch_size):
#             batch = whole_batch_list[i:i+batch_size]
    
#             future= executor.submit(process_batch_fuel, batch, data,  result_cols, log_file, merge_fuel )
#             futures.append(future)
#         concurrent.futures.wait(futures)



# def process_batch_fuel(batch_list, data, results_cols, log_file,  merge_fuel ):
#     results = [] 
#     if len(batch_list) ==0:
#         raise ValueError('empty batch')
#     for item in batch_list:
#         print(item)
#         item_results = postcode_fuel_vars_batch_fn(item, data, merge_fuel)
#         print(item_results)
#         results.append(item_results)
#     print(results)
#     if len(results) != len(batch_list):
#         raise ValueError('Results length does not match batch length')
#     df = pd.DataFrame(results, columns=results_cols )
#     # Get the temp file path and whether it's the first write operation
#     temp_file_path, is_first_write = get_thread_temp_file(log_file)
#     print('temp file path is ' , temp_file_path )
#     # Open the file with 'a' mode to append and ensure headers are written correctly
#     with open(temp_file_path, 'a') as f:
#         df.to_csv(f, header=is_first_write, index=False)
    
#     # Update the flag to indicate the header should not be written next time
#     if is_first_write:
#         thread_local.temp_file_first_write = False

#     print('temp file saved for batch')


# def get_thread_temp_file(log_file):
#     if not hasattr(thread_local, 'temp_file'):
#         temp_dir = os.path.dirname(log_file)

#         temp_file = tempfile.NamedTemporaryFile(delete=False, mode='w+', suffix='.csv', prefix='temp_log_', dir=temp_dir)        

#         thread_local.temp_file = temp_file.name
#         thread_local.temp_file_first_write = True
#     return thread_local.temp_file, thread_local.temp_file_first_write

# %%
# !pwd
# import os 

# # change working dir 
# os.chdir('/Users/gracecolverd/New_dataset') 

# ######## Area variables  ########
# col_name = 'postcode'
# attribute = 'gas_metric'

# result_cols = ['postcode', 'status', str(attribute) ]
# batch_fn = postcode_fuel_vars_batch_fn 
# postcode_area_bool=False 
# gen_fuel_bool=True 

# fuel_year = 2022 
# fuel_path =  f'/Volumes/T9/Data_downloads/UKGOV_Gas_elec/Postcode_level_gas_{fuel_year}.csv' #gas by postcode 


# ######## Settings variables ########
# batch_size = 15
# max_workers = 1

# def main():
#     base_dir = '/Users/gracecolverd/New_dataset'
#     print('Finding data for ONSUD file')
#     pc_df , data = find_postcode_for_ONSUD_file('/Volumes/T9/Data_downloads/ONS_UPRN_database/ONSUD_DEC_2022/Data/ONSUD_DEC_2022_EE.csv' )
#     lab = 'EE'

#     full_list = data['PCDS'].unique()   
#     print(len(full_list))
#     output_dir = os.path.join(base_dir, f'data/postcode_attributes/{attribute}' )
#     os.makedirs(output_dir, exist_ok=True)
#     log_file =  os.path.join(output_dir, f'{lab}_{attribute}_log.csv' )    
    


#     print('starting merge')
#     merge_temp_logs_to_main(log_file) 

#     whole_batch_list = generate_batch_list(full_list, log_file, col_name  )
    
#     print(len(whole_batch_list  ))

#     if gen_fuel_bool ==True: 
#         fuel_df = pd.read_csv(fuel_path )
#         merge_fuel = fuel_df[fuel_df['Postcode'].isin(whole_batch_list ) ][['Postcode', 'Total_cons_kwh']].copy() 

#     if len(merge_fuel) ==0:
#         raise ValueError('Empty fuel')
    
  
#     run_batching(whole_batch_list= whole_batch_list, batch_fn =  batch_fn , result_cols = result_cols, data = data,   log_file = log_file, batch_size = batch_size, max_workers=max_workers, merge_fuel = merge_fuel) 
#     merge_temp_logs_to_main(log_file) 
#     print('Attribute calculation complete')


# main()

# %%
# building types
